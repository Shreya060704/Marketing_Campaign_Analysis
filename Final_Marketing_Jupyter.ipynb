# %%
                                                          IMOPRTING THE DATABASE

# %%
import pandas as pd

df=pd.read_excel(r'C:\Users\hp\Downloads\Mar.xlsx')
df
# Out:
#       Campaign_ID              Company Campaign_Type Target_Audience Gender  \
# 0               1  Innovate Industries         Email       Men 18-24    Men
# 1               2       NexGen Systems         Email     Women 35-44  Women
# 2               3    Alpha Innovations    Influencer       Men 25-34    Men
# 3               4   DataTech Solutions       Display        All Ages    All
# 4               5       NexGen Systems         Email       Men 25-34    Men
# ...           ...                  ...           ...             ...    ...
# 1004         1005       NexGen Systems    Influencer       Men 25-34    Men
# 1005         1006  Innovate Industries    Influencer     Women 35-44  Women
# 1006         1007       NexGen Systems    Influencer       Men 18-24    Men
# 1007         1008       NexGen Systems         Email     Women 25-34  Women
# 1008         1009       NexGen Systems         Email        All Ages    All
#
# ...

# %%
                                                        BASIC INFORMATION ABOUT THE DATASET

# %%
# Calculate the median for all numerical columns
median_values = df.median(numeric_only=True)
print("Median values for numerical columns:")
print(median_values)
# Out:
# Median values for numerical columns:
# Campaign_ID           505.00
# Conversion_Rate         0.08
# Acquisition_Cost    12282.00
# ROI                     5.06
# Clicks                515.00
# Impressions          5735.00
# Engagement_Score        6.00
# dtype: float64

# %%
# Calculate the mode for all columns
mode_values = df.mode()
print("\nMode values for all columns (first mode shown if multiple modes exist):")
print(mode_values.iloc[0])
# Out:
# Mode values for all columns (first mode shown if multiple modes exist):
# Campaign_ID                           1
# Company             Innovate Industries
# Campaign_Type                Influencer
# Target_Audience               Men 25-34
# Gender                              Men
# Age                               25-34
# Duration                        30 days
# Channel_Used                  Instagram
# Conversion_Rate                    0.06
# Acquisition_Cost                 5478.0
# ROI                                 3.7
# Location                    Los Angeles
# Language                        English
# Clicks                            268.0
# Impressions                      1268.0
# Engagement_Score                    7.0
# Customer_Segment                Foodies
# Date                2021-01-01 00:00:00
# Name: 0, dtype: object
# ...

# %%
df.describe()

#THIS GIVES THE COUNT, MAX, MIN, STD OF THE WHOLE DATASET
# Out:
#        Campaign_ID  Conversion_Rate  Acquisition_Cost          ROI  \
# count  1009.000000      1009.000000       1009.000000  1009.000000
# mean    505.000000         0.079911      12364.430129     5.046838
# std     291.417513         0.040685       4379.997133     1.715779
# min       1.000000         0.010000       5020.000000     2.010000
# 25%     253.000000         0.050000       8560.000000     3.560000
# 50%     505.000000         0.080000      12282.000000     5.060000
# 75%     757.000000         0.120000      16116.000000     6.500000
# max    1009.000000         0.150000      19999.000000     8.000000
#
#             Clicks  Impressions  Engagement_Score
# count  1009.000000  1009.000000       1009.000000
# mean    528.164519  5633.910803          5.522299
# std     258.948842  2683.694730          2.874309
# min     100.000000  1005.000000          1.000000
# 25%     300.000000  3239.000000          3.000000
# 50%     515.000000  5735.000000          6.000000
# ...

# %%
print(df.info())

#THIS SHOWS THE DATATPYE AND THE NOT NULL COUNT OF ALL THE COLUMNS IN THE DATASET
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       1009 non-null   int64
#  1   Company           1009 non-null   object
#  2   Campaign_Type     1009 non-null   object
#  3   Target_Audience   1009 non-null   object
#  4   Gender            1009 non-null   object
#  5   Age               1009 non-null   object
#  6   Duration          1009 non-null   object
#  7   Channel_Used      1009 non-null   object
#  8   Conversion_Rate   1009 non-null   float64
#  9   Acquisition_Cost  1009 non-null   int64
#  10  ROI               1009 non-null   float64
#  11  Location          1009 non-null   object
#  12  Language          1009 non-null   object
#  13  Clicks            1009 non-null   int64
#  14  Impressions       1009 non-null   int64
#  15  Engagement_Score  1009 non-null   int64
# ...

# %%
                                                              DATA CLEANING

# %%
print(df.isnull().sum())

#CHECKS IF THERE IS A NULL DATA IN THE DATASET
# Out:
# Campaign_ID         0
# Company             0
# Campaign_Type       0
# Target_Audience     0
# Gender              0
# Age                 0
# Duration            0
# Channel_Used        0
# Conversion_Rate     0
# Acquisition_Cost    0
# ROI                 0
# Location            0
# Language            0
# Clicks              0
# Impressions         0
# Engagement_Score    0
# Customer_Segment    0
# Date                0
# dtype: int64

# %%
Null_row=df[df['Duration'].isnull()]
print(Null_row)
# Out:
# Empty DataFrame
# Columns: [Campaign_ID, Company, Campaign_Type, Target_Audience, Gender, Age, Duration, Channel_Used, Conversion_Rate, Acquisition_Cost, ROI, Location, Language, Clicks, Impressions, Engagement_Score, Customer_Segment, Date]
# Index: []

# %%
df=df.dropna(subset=['Duration'])

# %%
print(df.isnull().sum())
# Out:
# Campaign_ID         0
# Company             0
# Campaign_Type       0
# Target_Audience     0
# Gender              0
# Age                 0
# Duration            0
# Channel_Used        0
# Conversion_Rate     0
# Acquisition_Cost    0
# ROI                 0
# Location            0
# Language            0
# Clicks              0
# Impressions         0
# Engagement_Score    0
# Customer_Segment    0
# Date                0
# dtype: int64

# %%
print(df.dtypes)

#THIS IS DONE TO CHECK THE DATATYPE OF THE COLUMNS
# Out:
# Campaign_ID           int64
# Company              object
# Campaign_Type        object
# Target_Audience      object
# Gender               object
# Age                  object
# Duration             object
# Channel_Used         object
# Conversion_Rate     float64
# Acquisition_Cost      int64
# ROI                 float64
# Location             object
# Language             object
# Clicks                int64
# Impressions           int64
# Engagement_Score      int64
# Customer_Segment     object
# Date                 object
# dtype: object

# %%
#CHANGING THE DATATPYE OF THE REQUIRED COLUMNS

df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y', errors='coerce')

df['Company'] = df['Company'].astype('category')


df['Campaign_Type'] = df['Campaign_Type'].astype('category')



df['Target_Audience'] = df['Target_Audience'].astype('category')


df['Channel_Used'] = df['Channel_Used'].astype('category')


df['Language'] = df['Language'].astype('category')


df['Customer_Segment'] = df['Customer_Segment'].astype('category')

# %%
print(df.dtypes)

#PRINTS THE DATATYPES OF THE COLUMNS INCLUDING THE CHANGED ONES
# Out:
# Campaign_ID                  int64
# Company                   category
# Campaign_Type             category
# Target_Audience           category
# Gender                      object
# Age                         object
# Duration                    object
# Channel_Used              category
# Conversion_Rate            float64
# Acquisition_Cost             int64
# ROI                        float64
# Location                    object
# Language                  category
# Clicks                       int64
# Impressions                  int64
# Engagement_Score             int64
# Customer_Segment          category
# Date                datetime64[ns]
# dtype: object

# %%
                                                         EXPLORATORY DATA ANALYSIS

# %%
#COUNTS

campaign_type_distribution = df['Campaign_Type'].value_counts()
channel_type_distribution = df['Channel_Used'].value_counts()
Target_audience_distribution = df['Target_Audience'].value_counts()
Language_distribution = df['Language'].value_counts()
Customer_Segment_distribution = df['Customer_Segment'].value_counts()

print(campaign_type_distribution)
print("\n",channel_type_distribution)
print("\n",Target_audience_distribution)
print("\n",Language_distribution)
print("\n",Customer_Segment_distribution)
# Out:
# Campaign_Type
# Influencer      227
# Display         207
# Email           205
# Social Media    194
# Search          176
# Name: count, dtype: int64
#
#  Channel_Used
# Instagram     189
# Email         185
# Google Ads    168
# YouTube       168
# Facebook      155
# Website       144
# Name: count, dtype: int64
#
#  Target_Audience
# Men 25-34      217
# Men 18-24      212
# All Ages       210
# Women 35-44    195
# Women 25-34    175
# Name: count, dtype: int64
#
#  Language
# English     213
# Spanish     209
# German      198
# Mandarin    195
# French      194
# Name: count, dtype: int64
#
#  Customer_Segment
# Foodies                227
# Tech Enthusiasts       220
# Health & Wellness      200
# Fashionistas           186
# Outdoor Adventurers    176
# Name: count, dtype: int64

# %%
                                                        CAMPAIGN TYPE ANALYSIS

# %%
#DISTRIBUTION OF CAMPAIGN TYPES

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Campaign_Type', hue='Campaign_Type', palette='pastel', legend=False)
plt.title("Distribution of Campaign_Type")
plt.xlabel("Campaign Type")
plt.ylabel("Count")
plt.show()

# %%
#CAMPAIGN TYPE GROUPED BY CONVERSION RATE

average_conversion_rate_by_campaign = df.groupby('Campaign_Type')['Conversion_Rate'].mean().sort_values(ascending=False)

print("Average Conversion Rate for each Campaign_Type:")
print(average_conversion_rate_by_campaign)

average_conversion_rate_by_campaign.plot(kind='bar', color='skyblue', figsize=(8, 5))
plt.title('Average Conversion Rate by Campaign Type')
plt.xlabel('Campaign Type')
plt.ylabel('Average Conversion Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9372\1813534315.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_conversion_rate_by_campaign = df.groupby('Campaign_Type')['Conversion_Rate'].mean().sort_values(ascending=False)
# Average Conversion Rate for each Campaign_Type:
# Campaign_Type
# Email           0.082439
# Influencer      0.082247
# Social Media    0.080876
# Display         0.077295
# Search          0.075966
# Name: Conversion_Rate, dtype: float64

# %%
#CAMPAIGN TYPE GROUPED BY ROI

average_roi_by_campaign = df.groupby('Campaign_Type')['ROI'].mean().sort_values(ascending=False)

print("Average ROI for each Campaign_Type:")
print(average_roi_by_campaign)

average_roi_by_campaign.plot(kind='bar', color='pink', figsize=(8, 5))
plt.title('Average ROI by Campaign Type')
plt.xlabel('Campaign Type')
plt.ylabel('Average ROI')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_20464\1847903795.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_roi_by_campaign = df.groupby('Campaign_Type')['ROI'].mean().sort_values(ascending=False)
# Average ROI for each Campaign_Type:
# Campaign_Type
# Search          5.131477
# Social Media    5.080928
# Influencer      5.016520
# Email           5.014585
# Display         5.008116
# Name: ROI, dtype: float64

# %%
#CAMPAIGN TYPE GROUPED ACQUISITION COST

average_acquisition_cost_by_campaign = df.groupby('Campaign_Type')['Acquisition_Cost'].mean().sort_values(ascending=False)

print("Average Acquisition Cost for each Campaign_Type:")
print(average_acquisition_cost_by_campaign)

average_acquisition_cost_by_campaign.plot(kind='bar', color='pink', figsize=(8, 5))
plt.title('Average Acquisition Cost by Campaign Type')
plt.xlabel('Campaign Type')
plt.ylabel('Average Acquisition Cost')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9372\4262683034.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_acquisition_cost_by_campaign = df.groupby('Campaign_Type')['Acquisition_Cost'].mean().sort_values(ascending=False)
# Average Acquisition Cost for each Campaign_Type:
# Campaign_Type
# Email           12964.848780
# Social Media    12566.386598
# Influencer      12392.000000
# Search          11970.511364
# Display         11885.231884
# Name: Acquisition_Cost, dtype: float64

# %%
                                                             TARGET AUDUIENCE ANALYSIS

# %%
#DOMINANT TARGET AUDIENCE DISTRIBUTION

plt.figure(figsize=(6,6))
Target_audience_distribution.plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title("Dominant Target Audience")
plt.show()

# %%
#TARGET AUDIENCE GROUPED BY ROI

average_Target_Audience_by_campaign = df.groupby('Target_Audience')['ROI'].mean().sort_values(ascending=False)

print("Average ROI for each Target Audience:")
print(average_Target_Audience_by_campaign)

average_Target_Audience_by_campaign.plot(kind='bar', color='pink', figsize=(8, 5))
plt.title('Average ROI by Target Audience')
plt.xlabel('Target Audience')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9372\703147762.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_Target_Audience_by_campaign = df.groupby('Target_Audience')['ROI'].mean().sort_values(ascending=False)
# Average ROI for each Target Audience:
# Target_Audience
# Women 35-44    5.193077
# All Ages       5.123714
# Men 18-24      5.090613
# Men 25-34      4.982857
# Women 25-34    4.817943
# Name: ROI, dtype: float64

# %%
                                                                    CHANNEL USED ANALYSIS

# %%
#MOST FREQUENTLY USED CHANNEL

plt.figure(figsize=(8,5))
channel_type_distribution.plot(kind='barh', color="skyblue")
plt.title("Frequent Used Channel")
plt.xlabel("Count")
plt.ylabel("Used Channel")
plt.show()

# %%
#CONVERSION RATE AND ROI BY CHANNEL

average_conversion_rate_by_channel = df.groupby('Channel_Used')['Conversion_Rate'].mean().sort_values(ascending=False)
average_roi_by_channel = df.groupby('Channel_Used')['ROI'].mean().sort_values(ascending=False)

print("Average Conversion Rate by Channel:")
print(average_conversion_rate_by_channel)

print("Average ROI by Channel:")
print(average_roi_by_channel)

average_conversion_rate_by_channel.plot(kind='bar', color='skyblue', figsize=(8, 5))
plt.title('Average Conversion Rate by Channel')
plt.xlabel('Channel')
plt.ylabel('Average Conversion Rate')
plt.xticks(rotation=45)
plt.show()

average_roi_by_channel.plot(kind='bar', color='pink', figsize=(8, 5))
plt.title('Average ROI by Channel')
plt.xlabel('Channel')
plt.ylabel('Average ROI')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9372\721455464.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_conversion_rate_by_channel = df.groupby('Channel_Used')['Conversion_Rate'].mean().sort_values(ascending=False)
# C:\Program Files\KMSpico\temp\ipykernel_9372\721455464.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_roi_by_channel = df.groupby('Channel_Used')['ROI'].mean().sort_values(ascending=False)
# Average Conversion Rate by Channel:
# Channel_Used
# Google Ads    0.087321
# Email         0.082595
# Facebook      0.079419
# Website       0.078611
# Instagram     0.077460
# ...

# %%
                                                                 LOCATION ANALYSIS

# %%
#CONVERSION RATE BY LOCATION

conversion_rate_by_location = df.groupby('Location')['Conversion_Rate'].mean()

print("\nAverage Conversion Rate by Location:")
print(conversion_rate_by_location)

conversion_rate_by_location.plot(kind='bar', color='pink', figsize=(8, 5))
plt.title('Average Conversion Rate by Location')
plt.xlabel('Location')
plt.ylabel('Conversion Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# Average Conversion Rate by Location:
# Location
# Chicago        0.082696
# Houston        0.079903
# Los Angeles    0.079811
# Miami          0.077879
# New York       0.079153
# Name: Conversion_Rate, dtype: float64

# %%
#ENGAGMENT SCORE BY LOCATION
engagement_rate_by_location = df.groupby('Location')['Engagement_Score'].mean()
print("\nAverage Engagement_Score by Location:")
print(engagement_rate_by_location)
# Out:
# Average Engagement_Score by Location:
# Location
# Chicago        5.916667
# Houston        5.296117
# Los Angeles    5.570755
# Miami          5.545455
# New York       5.264550
# Name: Engagement_Score, dtype: float64

# %%
                                                         COSTUMER SEGMENT ANALYSIS

# %%
#CONVERSION RATE AND ROI BY CUSTOMER SEGMENT

conversion_rate_by_segment = df.groupby('Customer_Segment')['Conversion_Rate'].mean()
roi_by_segment = df.groupby('Customer_Segment')['ROI'].mean().sort_values(ascending=False)

print("\nAverage Conversion Rate by Customer Segment:")
print(conversion_rate_by_segment)

print("\nAverage ROI by Customer Segment:")
print(roi_by_segment)

conversion_rate_by_segment.plot(kind='bar', color='pink', figsize=(8, 5))
plt.title('Average Conversion Rate by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Conversion Rate')
plt.xticks(rotation=45)
plt.show()

roi_by_segment.plot(kind='bar', color='skyblue', figsize=(8, 5))
plt.title('Average ROI by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9372\2806698593.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   conversion_rate_by_segment = df.groupby('Customer_Segment')['Conversion_Rate'].mean()
# C:\Program Files\KMSpico\temp\ipykernel_9372\2806698593.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   roi_by_segment = df.groupby('Customer_Segment')['ROI'].mean().sort_values(ascending=False)
# Average Conversion Rate by Customer Segment:
# Customer_Segment
# Fashionistas           0.078656
# Foodies                0.085903
# Health & Wellness      0.080150
# Outdoor Adventurers    0.074716
# ...

# %%
                                                                SEASONAL TRENDS ANALYSIS

# %%
df['Date'] = pd.to_datetime(df['Date'])


df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# %%
monthly_trends = df.groupby('Month')[['Conversion_Rate', 'ROI','Engagement_Score']].mean().reset_index()


print(monthly_trends)
# Out:
#     Month  Conversion_Rate       ROI  Engagement_Score
# 0       1         0.080753  5.037742          5.301075
# 1       2         0.074524  5.079167          5.571429
# 2       3         0.084194  5.171613          5.688172
# 3       4         0.078111  4.969667          5.411111
# 4       5         0.084731  5.003548          5.161290
# 5       6         0.075111  5.132556          5.833333
# 6       7         0.085914  5.046022          6.000000
# 7       8         0.069892  4.952366          5.279570
# 8       9         0.083889  5.067222          5.600000
# 9      10         0.077206  5.355882          5.161765
# 10     11         0.085500  4.733167          5.650000
# 11     12         0.079677  4.960000          5.596774

# %%
#MONTHLY TRENDS IN CONVERSION RATE

plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_trends, x='Month', y='Conversion_Rate', marker='o', label='Conversion Rate')
plt.title('Seasonal Trends in Conversion Rate (Monthly)')
plt.xlabel('Month')
plt.ylabel('Conversion Rate')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid()
plt.show()

# %%
#SEASONAL TRENDS IN ROI

plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_trends, x='Month', y='ROI', marker='o', label='ROI')
plt.title('Seasonal Trends in ROI (Monthly)')
plt.xlabel('Month')
plt.ylabel('ROI')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid()
plt.show()

# %%
#SEASONAL TRENS IN THE ENGAGEMENT SCORE (MONTHLY)

plt.figure(figsize=(10, 6))
sns.lineplot(data=monthly_trends, x='Month', y='Engagement_Score', marker='o', label='Engagement_Score')
plt.title('Seasonal Trends in Engagement_Score (Monthly)')
plt.xlabel('Month')
plt.ylabel('Engagement_Score')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid()
plt.show()

# %%
                                                            DISTRIBUTION ANALYSIS

# %%
#DISTRIBUTION OF CONVERSION RATE

df['Conversion_Rate'].hist(bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Conversion Rate')
plt.xlabel('Conversion Rate')
plt.ylabel('Frequency')
plt.show()

# %%
#DISTRIBUTION OF ROI

df['ROI'].hist(bins=20, color='pink', edgecolor='black')
plt.title('Distribution of ROI')
plt.xlabel('ROI')
plt.ylabel('Frequency')
plt.show()

# %%
#DISTRIBUTION OF ACQUISITION COST

df['Acquisition_Cost'].hist(bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Acquisition Cost')
plt.xlabel('Acquisition Cost')
plt.ylabel('Frequency')
plt.show()

# %%
#DISTRIBUTION OF ROI BY LANGUAGE AND LOCATION

lang_loca_analysis=df.groupby(['Language','Location'])[['Conversion_Rate', 'ROI']].mean().reset_index()
plt.figure(figsize=(14, 8))
sns.barplot(data=lang_loca_analysis, x='Location', y='ROI', hue='Language', palette='viridis')
plt.title('ROI by Language and Location')
plt.legend(title='Language')
plt.show()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_9372\4115536653.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   lang_loca_analysis=df.groupby(['Language','Location'])[['Conversion_Rate', 'ROI']].mean().reset_index()

# %%
                                                              HEAT MAPS

# %%
#HEAT MAP FOR ALL THE NUMERICAL COLUMNS

numerical_columns = ['Clicks', 'Impressions', 'Engagement_Score', 'Conversion_Rate', 'ROI']

# Correlation matrix
correlation_matrix = df[numerical_columns].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
#HEATMAP FOR CONVERSION RATE BY LANGUAGE AND LOCATION

heatmap_data = lang_loca_analysis.pivot(index='Language', columns='Location', values='Conversion_Rate')

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)
plt.title('Conversion Rate by Language and Location')
plt.show()

# %%
                                                       SOME STAKEHOLDER QUESTIONS

# %%
Q1. Identify which Channel_Used delivers the highest ROI and Conversion_Rate.

# %%
#CHANNEL WITH HIGHEST ROI

average_Channel_Used_by_campaign = df.groupby('Channel_Used')['ROI'].mean().sort_values(ascending=False)

print("Average Channel_Used for each ROI:")
print(average_Channel_Used_by_campaign)

#FACEBOOK HAS THE HIGHEST ROI
# Out:
# Average Channel_Used for each ROI:
# Channel_Used
# Facebook      5.228323
# YouTube       5.203333
# Google Ads    5.097917
# Email         4.977838
# Website       4.937986
# Instagram     4.863968
# Name: ROI, dtype: float64
# C:\Program Files\KMSpico\temp\ipykernel_9372\1305028898.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_Channel_Used_by_campaign = df.groupby('Channel_Used')['ROI'].mean().sort_values(ascending=False)

# %%
#CHANNEL WITH HIGHEST CONVERSION RATE

average_Channel_Used_by_convertion = df.groupby('Channel_Used')['Conversion_Rate'].mean().sort_values(ascending=False)

print("Average Channel_Used for each Conversion_rate")
print(average_Channel_Used_by_convertion)

# GOOGLE ADS IS THE MOST USED CHANNEL
# Out:
# Average Channel_Used for each Conversion_rate
# Channel_Used
# Google Ads    0.087321
# Email         0.082595
# Facebook      0.079419
# Website       0.078611
# Instagram     0.077460
# YouTube       0.073869
# Name: Conversion_Rate, dtype: float64
# C:\Program Files\KMSpico\temp\ipykernel_9372\1957760126.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_Channel_Used_by_convertion = df.groupby('Channel_Used')['Conversion_Rate'].mean().sort_values(ascending=False)

# %%
Q2. Understand which Target_Audience segments respond best to campaigns.

# %%
#TARGET AUDIENCE THAT RESPONDS BEST TO THE CAMPAIGNS

avg_target_Campaign=df.groupby('Target_Audience')['Campaign_Type'].count().sort_values(ascending=False)
print(avg_target_Campaign)


#MEN 25-34 RESPONSD BEST TO CAMPAIGNS
# Out:
# Target_Audience
# Men 25-34      217
# Men 18-24      212
# All Ages       210
# Women 35-44    195
# Women 25-34    175
# Name: Campaign_Type, dtype: int64
# C:\Program Files\KMSpico\temp\ipykernel_9372\835112170.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_target_Campaign=df.groupby('Target_Audience')['Campaign_Type'].count().sort_values(ascending=False)

# %%
Q3. Which Locations have the highest engagement and conversion?

# %%
#LOCATION WITH HIGHEST ENGAGEMENT SCORE

engagement_rate_by_location = df.groupby('Location')['Engagement_Score'].mean()
print("\nAverage Engagement_Score by Location:")
print(engagement_rate_by_location)

#Chicago has the highest engagement_score
# Out:
# Average Engagement_Score by Location:
# Location
# Chicago        5.916667
# Houston        5.296117
# Los Angeles    5.570755
# Miami          5.545455
# New York       5.264550
# Name: Engagement_Score, dtype: float64

# %%
#LOCATION WITH HIGHEST CONVERSION RATE

language_group = df.groupby('Language').agg({
    'Conversion_Rate': ['mean', 'std'], 
    'Acquisition_Cost': ['mean', 'std'],  
    'ROI': ['mean', 'std'],  
    'Engagement_Score': ['mean', 'std'],  
}).reset_index()

# Display the results
print(language_group)
# Out:
#    Language Conversion_Rate           Acquisition_Cost                    ROI  \
#                        mean       std             mean          std      mean
# 0   English        0.074131  0.038593     12940.037559  4529.182904  5.014272
# 1    French        0.079639  0.040147     12415.422680  4256.976114  4.920155
# 2    German        0.081212  0.040861     11582.151515  4298.305218  5.151111
# 3  Mandarin        0.083333  0.043407     12838.302564  4434.445021  5.001949
# 4   Spanish        0.081627  0.040242     12029.449761  4261.552829  5.140718
#
#             Engagement_Score
#         std             mean       std
# 0  1.764404         5.455399  2.805677
# 1  1.710538         5.510309  2.890470
# 2  1.645321         5.409091  2.916663
# 3  1.741276         5.800000  2.862124
# 4  1.717449         5.449761  2.910295
# ...

# %%
                                                          SOME OTHER ANALYSIS

# %%
roi_by_age = df.groupby('Age')['ROI'].mean().sort_values(ascending=False)
print("ROI by Age Group:\n", roi_by_age)

roi_by_gender = df.groupby('Gender')['ROI'].mean().sort_values(ascending=False)
print("ROI by Gender:\n", roi_by_gender)

roi_by_segment = df.groupby('Customer_Segment')['ROI'].mean().sort_values(ascending=False)
print("ROI by Customer Segment:\n", roi_by_segment)

correlation = df[['Engagement_Score', 'Conversion_Rate', 'ROI']].corr()
print("Correlation Matrix:\n", correlation)

avg_engagement_by_channel = df.groupby('Channel_Used')['Engagement_Score'].mean().sort_values(ascending=False)
print("Engagement Score by Channel:\n", avg_engagement_by_channel)

conversion_by_channel = df.groupby('Channel_Used')['Conversion_Rate'].mean().sort_values(ascending=False)
print("Conversion Rate by Channel:\n", conversion_by_channel)

roi_by_campaign = df.groupby('Campaign_Type')['ROI'].mean().sort_values(ascending=False)
roi_by_channel = df.groupby('Channel_Used')['ROI'].mean().sort_values(ascending=False)
print("ROI by Campaign Type:\n", roi_by_campaign)
print("ROI by Channel:\n", roi_by_channel)
# Out:
# ROI by Age Group:
#  Age
# 35-44       5.193077
# All Ages    5.123714
# 18-24       5.090613
# 25-34       4.909235
# Name: ROI, dtype: float64
# ROI by Gender:
#  Gender
# All      5.123714
# Men      5.036107
# Women    5.015649
# Name: ROI, dtype: float64
# ROI by Customer Segment:
#  Customer_Segment
# Outdoor Adventurers    5.109432
# Foodies                5.051278
# Tech Enthusiasts       5.050227
# Health & Wellness      5.024600
# Fashionistas           5.002097
# Name: ROI, dtype: float64
# Correlation Matrix:
#                    Engagement_Score  Conversion_Rate       ROI
# Engagement_Score          1.000000         0.043665 -0.025965
# Conversion_Rate           0.043665         1.000000 -0.038737
# ROI                      -0.025965        -0.038737  1.000000
# Engagement Score by Channel:
#  Channel_Used
# Facebook      5.612903
# Website       5.562500
# Instagram     5.560847
# Email         5.529730
# Google Ads    5.446429
# YouTube       5.428571
# ...
